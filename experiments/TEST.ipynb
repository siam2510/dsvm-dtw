# %%
import pandas as pd
df1 = pd.read_csv(
    r"C:\Users\siam2\Desktop\dsvm-dtw\results\ECG5000_test_outcontrol_p_swk_matrix_ecd_original(0~99)_bootstrap_seed2025_m=100.csv", index_col=0)
df1
# Out:
#        rep_0     rep_1     rep_2     rep_3     rep_4     rep_5     rep_6  \
# t
# 0   0.325373  0.341540  0.311261  0.326877  0.301025  0.339518  0.322968
# 1   0.342829  0.364595  0.371616  0.359668  0.348444  0.334081  0.323347
# 2   0.348565  0.371272  0.358000  0.396180  0.377423  0.384538  0.366029
# 3   0.391261  0.390865  0.410427  0.404186  0.395516  0.399014  0.399339
# 4   0.417983  0.422614  0.437260  0.391866  0.404784  0.406289  0.402585
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.730135  0.734437  0.737805  0.728372  0.741213  0.744875  0.726609
# 96  0.730268  0.734909  0.738537  0.728542  0.745429  0.739555  0.727832
# 97  0.729928  0.735385  0.738868  0.729492  0.745461  0.741732  0.726986
# 98  0.727680  0.735354  0.743126  0.727683  0.745135  0.739017  0.726118
# 99  0.730313  0.737875  0.742121  0.727772  0.743368  0.734306  0.725236
#
#        rep_7     rep_8     rep_9  ...    rep_90    rep_91    rep_92    rep_93  \
# ...

# %%
df2 = pd.read_csv(
    r"C:\Users\siam2\Desktop\dsvm-dtw\results\ECG5000_test_outcontrol_p_swk_matrix_ecd_original(0~49)_bootstrap_seed2025_m=100.csv", index_col=0)

df3 = pd.read_csv(
    r"C:\Users\siam2\Desktop\dsvm-dtw\results\ECG5000_test_outcontrol_p_swk_matrix_ecd_original(50~99)_bootstrap_seed2025_m=100.csv", index_col=0)

# df2와 df3을 가로 방향으로 합쳐서 df4에 저장
df4 = pd.concat([df2, df3], axis=1)
df4
# Out:
#        rep_0     rep_1     rep_2     rep_3     rep_4     rep_5     rep_6  \
# t
# 0   0.325373  0.341540  0.311261  0.326877  0.301025  0.339518  0.322968
# 1   0.342829  0.364595  0.371616  0.359668  0.348444  0.334081  0.323347
# 2   0.348565  0.371272  0.358000  0.396180  0.377423  0.384538  0.366029
# 3   0.391261  0.390865  0.410427  0.404186  0.395516  0.399014  0.399339
# 4   0.417983  0.422614  0.437260  0.391866  0.404784  0.406289  0.402585
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.730135  0.734437  0.737805  0.728372  0.741213  0.744875  0.726609
# 96  0.730268  0.734909  0.738537  0.728542  0.745429  0.739555  0.727832
# 97  0.729928  0.735385  0.738868  0.729492  0.745461  0.741732  0.726986
# 98  0.727680  0.735354  0.743126  0.727683  0.745135  0.739017  0.726118
# 99  0.730313  0.737875  0.742121  0.727772  0.743368  0.734306  0.725236
#
#        rep_7     rep_8     rep_9  ...    rep_90    rep_91    rep_92    rep_93  \
# ...

# %%
# df1과 df4가 동일한지 확인
print(df1.equals(df4))
# Out:
# True
